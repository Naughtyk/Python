# %%
import pandas as pd
data = pd.read_csv('abalone.csv')
data['Sex'] = data['Sex'].map(lambda x: 1 if x == 'M' else (-1 if x == 'F' else 0))
y = data['Rings']
X = data.drop(['Rings'], axis=1)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

kf = KFold(n_splits = 5, shuffle = True, random_state = 1)
mas = []

for i in range(1, 51):
    regr = RandomForestRegressor(n_estimators = i, random_state = 1)

    mas += [cross_val_score(regr, X, y, cv = kf, scoring = 'r2')]

print(mas)
# Out:
# [array([ 0.19664192,  0.11762437,  0.25014945,  0.01794534, -0.03398699]), array([0.34998973, 0.31248787, 0.41442449, 0.29315165, 0.3364463 ]), array([0.43555625, 0.39450971, 0.4507151 , 0.34369426, 0.40769383]), array([0.4538912 , 0.43181681, 0.48833327, 0.40171715, 0.44811451]), array([0.46516582, 0.46183516, 0.50245236, 0.42456443, 0.4711443 ]), array([0.47016632, 0.46550248, 0.50380226, 0.44024387, 0.47726486]), array([0.47240359, 0.46311534, 0.51025053, 0.44945745, 0.48810233]), array([0.47827651, 0.47156308, 0.52085313, 0.45436419, 0.48961728]), array([0.48346912, 0.47368495, 0.52758124, 0.46537936, 0.49707042]), array([0.48225917, 0.48287088, 0.53756673, 0.46763961, 0.50670639]), array([0.48443577, 0.48035332, 0.53523372, 0.47505758, 0.49697519]), array([0.49359064, 0.48300729, 0.53465322, 0.4833414 , 0.50054834]), array([0.49857347, 0.4883515 , 0.53836004, 0.48430487, 0.5056994 ]), array([0.50562752, 0.49164162, 0.54044573, 0.48695012, 0.51191912]), array([0.50606455, 0.49852416, 0.54237997, 0.48970319, 0.50923312]), array([0.50493858, 0.50180559, 0.54536394, 0.49340094, 0.51154362]), array([0.51039121, 0.50738207, 0.54842465, 0.49471444, 0.5135465 ]), array([0.51097815, 0.5092563 , 0.55161048, 0.49878402, 0.51547284]), array([0.51321618, 0.51127243, 0.55476356, 0.50112136, 0.51877302]), array([0.51563775, 0.51133764, 0.55358689, 0.50040265, 0.51645683]), array([0.51584313, 0.51265805, 0.55548875, 0.49695939, 0.52169615]), array([0.51690369, 0.51408782, 0.55391558, 0.50110773, 0.5180073 ]), array([0.5170906 , 0.51672122, 0.55639749, 0.49911354, 0.51939143]), array([0.51623234, 0.5217244 , 0.55850082, 0.49632802, 0.52274441]), array([0.51532273, 0.52185267, 0.55971793, 0.49816775, 0.52118216]), array([0.51688867, 0.52540853, 0.55876872, 0.49825838, 0.52221378]), array([0.51735864, 0.52182571, 0.55936847, 0.4977467 , 0.52689728]), array([0.51667085, 0.52148422, 0.56102036, 0.50043358, 0.52866986]), array([0.51838442, 0.52214221, 0.5632146 , 0.50081945, 0.52821747]), array([0.52043619, 0.52011799, 0.56336706, 0.50316298, 0.52834513]), array([0.52327036, 0.51673414, 0.56374199, 0.50344563, 0.5310181 ]), array([0.52413271, 0.5179837 , 0.56425165, 0.50543056, 0.53282378]), array([0.52461756, 0.51853952, 0.56618725, 0.50865278, 0.53253975]), array([0.52399931, 0.51766562, 0.56637112, 0.50860069, 0.53317012]), array([0.52274291, 0.5188607 , 0.56614571, 0.50853881, 0.53281676]), array([0.52269894, 0.51968506, 0.56552554, 0.50853149, 0.53310923]), array([0.52136592, 0.51975836, 0.56625545, 0.50872108, 0.53105939]), array([0.52134515, 0.52000843, 0.56624493, 0.50671615, 0.53304303]), array([0.52058488, 0.52097804, 0.56719012, 0.50646873, 0.53235771]), array([0.5203169 , 0.52078275, 0.56516427, 0.50756769, 0.53352017]), array([0.51992748, 0.52230975, 0.56780478, 0.50594374, 0.53305809]), array([0.51983857, 0.52264961, 0.56767554, 0.50657683, 0.53347611]), array([0.52051503, 0.52117856, 0.56762915, 0.50744691, 0.53279823]), array([0.52021067, 0.52148467, 0.56800421, 0.5064816 , 0.53222633]), array([0.51806828, 0.52187536, 0.56712374, 0.50675188, 0.5307213 ]), array([0.51791879, 0.52168735, 0.56792384, 0.50624697, 0.53126459]), array([0.51758328, 0.51982817, 0.56827091, 0.50731389, 0.53289704]), array([0.51888906, 0.51992833, 0.56809671, 0.50827328, 0.53506733]), array([0.51989276, 0.52121002, 0.56798231, 0.50972235, 0.53525785]), array([0.51981875, 0.51994924, 0.56869935, 0.50969814, 0.53658909])]

# %%
for index, i in enumerate(mas):
    i = sum(i)/5
    print(index, round(i, 2))
# Out:
# 0 0.11
# 1 0.34
# 2 0.41
# 3 0.44
# 4 0.47
# 5 0.47
# 6 0.48
# 7 0.48
# 8 0.49
# 9 0.5
# 10 0.49
# 11 0.5
# 12 0.5
# 13 0.51
# 14 0.51
# 15 0.51
# 16 0.51
# 17 0.52
# 18 0.52
# 19 0.52
# 20 0.52
# 21 0.52
# 22 0.52
# 23 0.52
# 24 0.52
# 25 0.52
# 26 0.52
# 27 0.53
# 28 0.53
# 29 0.53
# 30 0.53
# 31 0.53
# 32 0.53
# 33 0.53
# 34 0.53
# 35 0.53
# 36 0.53
# 37 0.53
# 38 0.53
# 39 0.53
# 40 0.53
# 41 0.53
# 42 0.53
# 43 0.53
# 44 0.53
# 45 0.53
# 46 0.53
# 47 0.53
# 48 0.53
# 49 0.53
